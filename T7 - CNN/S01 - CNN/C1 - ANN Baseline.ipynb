# %% [markdown]
# # MNIST Data (Reduced)
#
# - This is a dataset of 60,000 28x28 grayscale images of the 10 digits, along with a test set of 10,000 images.
# - https://www.tensorflow.org/api_docs/python/tf/keras/datasets/mnist/load_data

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import itertools
import numpy as np
import pandas as pd

# %% [markdown]
# ## Data

# %%
mnist = tf.keras.datasets.mnist

(X_train_, y_train), (X_test_, y_test) = mnist.load_data()
X_train_, X_test_ = (
    X_train_.astype(np.float32) / 255.0,
    X_test_.astype(np.float32) / 255.0,
)

# %%
print(X_train_.shape)
print(X_test_.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)
# (60000,)
# (10000,)

# %%
# Reduce dimension size
np.random.seed(0)

REDUCE_DIM = 2000
idx = np.random.permutation(REDUCE_DIM)

X_train = X_train_[idx]
y_train = y_train[idx]
X_test = X_test_[idx]
y_test = y_test[idx]

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (2000, 28, 28)
# (2000, 28, 28)
# (2000,)
# (2000,)

# %% [markdown]
# ## Model building
#
# - Build the `tf.keras.Sequential` model by stacking layers. Choose an optimizer and loss function for training:

# %%
tf.keras.backend.clear_session()

model = tf.keras.models.Sequential(
    [
        tf.keras.layers.Input(shape=(28, 28)),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(128, activation="relu", name="hidden1"),
        tf.keras.layers.Dense(10, activation="softmax", name="output"),
    ]
)

# %% [markdown]
# ## Compile model
#
# - Prepare for fitting

# %%
model.compile(
    optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"]
)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  hidden1 (Dense)             (None, 128)               100480
#
#  output (Dense)              (None, 10)                1290
#
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training (Fitting)
#
# - The `Model.fit` method adjusts the model parameters to minimize the loss:

# %%
tf_fit = model.fit(X_train, y_train, validation_split=0.1, epochs=40)
# Out:
# Epoch 1/40
# 57/57 [==============================] - 1s 4ms/step - loss: 1.1283 - accuracy: 0.6939 - val_loss: 0.5848 - val_accuracy: 0.8450
# Epoch 2/40
# 57/57 [==============================] - 0s 2ms/step - loss: 0.4518 - accuracy: 0.8778 - val_loss: 0.4144 - val_accuracy: 0.9050
# Epoch 3/40
# 57/57 [==============================] - 0s 2ms/step - loss: 0.3366 - accuracy: 0.9083 - val_loss: 0.3679 - val_accuracy: 0.9050
# Epoch 4/40
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2577 - accuracy: 0.9367 - val_loss: 0.3480 - val_accuracy: 0.9150
# Epoch 5/40
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2061 - accuracy: 0.9511 - val_loss: 0.3497 - val_accuracy: 0.9050
# Epoch 6/40
# 57/57 [==============================] - 0s 3ms/step - loss: 0.1753 - accuracy: 0.9611 - val_loss: 0.3494 - val_accuracy: 0.9150
# Epoch 7/40
# 57/57 [==============================] - 0s 2ms/step - loss: 0.1427 - accuracy: 0.9667 - val_loss: 0.3352 - val_accuracy: 0.9100
# Epoch 8/40
# 57/57 [==============================] - 0s 3ms/step - loss: 0.1219 - accuracy: 0.9728 - val_loss: 0.3327 - val_accuracy: 0.9250
# Epoch 9/40
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0963 - accuracy: 0.9839 - val_loss: 0.3368 - val_accuracy: 0.9250
# Epoch 10/40
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0827 - accuracy: 0.9889 - val_loss: 0.3236 - val_accuracy: 0.9300
# Epoch 11/40
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0711 - accuracy: 0.9906 - val_loss: 0.3452 - val_accuracy: 0.9150
# Epoch 12/40
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0593 - accuracy: 0.9928 - val_loss: 0.3341 - val_accuracy: 0.9300
# Epoch 13/40
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0517 - accuracy: 0.9972 - val_loss: 0.3487 - val_accuracy: 0.9300
# Epoch 14/40
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0427 - accuracy: 0.9972 - val_loss: 0.3485 - val_accuracy: 0.9250
# Epoch 15/40
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0384 - accuracy: 0.9967 - val_loss: 0.3512 - val_accuracy: 0.9300
# Epoch 16/40
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0293 - accuracy: 0.9994 - val_loss: 0.3493 - val_accuracy: 0.9300
# Epoch 17/40
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0250 - accuracy: 0.9994 - val_loss: 0.3547 - val_accuracy: 0.9250
# Epoch 18/40
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0211 - accuracy: 0.9994 - val_loss: 0.3541 - val_accuracy: 0.9300
# Epoch 19/40
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0196 - accuracy: 0.9994 - val_loss: 0.3594 - val_accuracy: 0.9350
# Epoch 20/40
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0165 - accuracy: 1.0000 - val_loss: 0.3641 - val_accuracy: 0.9300
# Epoch 21/40
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0145 - accuracy: 1.0000 - val_loss: 0.3700 - val_accuracy: 0.9250
# Epoch 22/40
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 0.3775 - val_accuracy: 0.9300
# Epoch 23/40
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0114 - accuracy: 1.0000 - val_loss: 0.3802 - val_accuracy: 0.9350
# Epoch 24/40
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.3797 - val_accuracy: 0.9350
# Epoch 25/40
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.3823 - val_accuracy: 0.9300
# Epoch 26/40
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.3838 - val_accuracy: 0.9350
# Epoch 27/40
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.3851 - val_accuracy: 0.9300
# Epoch 28/40
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.3934 - val_accuracy: 0.9350
# Epoch 29/40
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.3925 - val_accuracy: 0.9300
# Epoch 30/40
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.3966 - val_accuracy: 0.9300
# Epoch 31/40
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.3979 - val_accuracy: 0.9300
# Epoch 32/40
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.4018 - val_accuracy: 0.9300
# Epoch 33/40
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.4024 - val_accuracy: 0.9300
# Epoch 34/40
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.4073 - val_accuracy: 0.9250
# Epoch 35/40
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.4094 - val_accuracy: 0.9350
# Epoch 36/40
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.4127 - val_accuracy: 0.9350
# Epoch 37/40
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.4143 - val_accuracy: 0.9350
# Epoch 38/40
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.4146 - val_accuracy: 0.9300
# Epoch 39/40
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.4199 - val_accuracy: 0.9350
# Epoch 40/40
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.4227 - val_accuracy: 0.9300

# %%
# Inspect the training history
df = pd.DataFrame(tf_fit.history)
df.head()
# Out:
#        loss  accuracy  val_loss  val_accuracy
# 0  1.128281  0.693889  0.584803         0.845
# 1  0.451827  0.877778  0.414364         0.905
# 2  0.336556  0.908333  0.367930         0.905
# 3  0.257743  0.936667  0.348030         0.915
# 4  0.206090  0.951111  0.349720         0.905

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 5))

df[["loss", "val_loss"]].plot(
    ax=axes[0], title="Loss", grid=True, legend=True, xlabel="Epoch", ylabel="Loss"
)

df[["accuracy", "val_accuracy"]].plot(
    ax=axes[1], title="Loss", grid=True, legend=True, xlabel="Epoch", ylabel="Loss"
)
# Out:
# <Axes: title={'center': 'Loss'}, xlabel='Epoch', ylabel='Loss'>

# %% [markdown]
# ## Evaluation
#
# - The `Model.evaluate` method checks the models performance.

# %%
model.evaluate(X_test, y_test)
# Out:
# 63/63 [==============================] - 0s 1ms/step - loss: 0.5419 - accuracy: 0.8740
# [0.541892945766449, 0.8740000128746033]

# %%
y_hat = model(X_test)
print(y_hat.shape)
print(y_hat.numpy()[:2])
# Out:
# (2000, 10)
# [[2.3924158e-09 5.6078071e-09 2.5790430e-06 4.7873904e-04 9.9798918e-01
#   3.7696876e-10 1.0033244e-10 1.1124717e-05 2.6099464e-10 1.5183240e-03]
#  [1.4397139e-07 1.2869629e-10 3.9528142e-10 1.5227626e-07 3.8583176e-10
#   9.9999750e-01 1.0672140e-11 3.5059546e-11 2.2379456e-06 7.5595167e-08]]

# %%
x_ticklabel = [i + 1 for i in range(10)]
fig, axes = plt.subplots(1, 2, figsize=(10, 5))
yp = y_hat.numpy()[0]
xp = list(range(yp.shape[0]))
axes[0].bar(xp, yp)
axes[0].set_title("Softmax Values")
axes[0].set_xticks(x_ticklabel)
axes[0].set_xticklabels(x_ticklabel)
axes[0].set_xlim([1, 10])
axes[1].imshow(X_test[0], cmap="gray")
plt.show()

# %%
# Find misclassification
y_pred_tf = model(X_test)
y_pred_tf.numpy().shape

y_pred = tf.math.argmax(y_pred_tf, axis=1).numpy()
print(y_pred.shape)
print(y_test.shape)

loc = y_pred != y_test
print(f"Missclassification = {loc.sum()}")
# Out:
# (2000,)
# (2000,)
# Missclassification = 252

# %%
fig, axes2D = plt.subplots(3, 5, figsize=(12, 8))
axes = list(itertools.chain.from_iterable(axes2D))  # Flatten 2D list
X_test_miss = X_test[loc]
y_test_miss = y_test[loc]
y_pred_miss = y_pred[loc]
for idx, ax in enumerate(axes):
    ax.imshow(X_test_miss[idx], cmap="gray")
    ax.set_title(f"True={y_test_miss[idx]}, Pred={y_pred_miss[idx]}")
fig.tight_layout()
plt.show()
