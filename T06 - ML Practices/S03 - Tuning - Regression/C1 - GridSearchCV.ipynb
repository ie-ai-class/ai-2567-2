# %% [markdown]
# # Parameter tuning for regression models
#
# ## GridSearchCV

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_percentage_error

# %% [markdown]
# ### Setting up

# %%
# Load data
df = pd.read_excel("./housing_data.xlsx")

# Extract data 
X = df[["LSTAT"]].values
y = df["MEDV"].values


# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# Standardize data
sc = StandardScaler()
X_train_std = sc.fit_transform(X_train)
X_test_std = sc.transform(X_test)

# Classifier
svr = SVR()

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
pd.DataFrame(data=svr.get_params(), index=["param"]).T
# Out:
#             param
# C             1.0
# cache_size    200
# coef0         0.0
# degree          3
# epsilon       0.1
# gamma       scale
# kernel        rbf
# max_iter       -1
# shrinking    True
# tol         0.001
# verbose     False

# %% [markdown]
# ### Define parameter sets

# %%
param_range = [0.0001, 0.001, 0.01, 0.1, 1.0, 10.0, 100.0, 1000.0]

set1 = {'C': param_range,
        'kernel': ['linear']}

set2 = {'C': param_range,
        'gamma': param_range,
        'kernel': ['rbf']}

param_grid = [set1, set2]

# %% [markdown]
# ### GridSearchCV classifier
#
# - Don't forget to change the scoring function.

# %%
gs = GridSearchCV(estimator=svr, 
                  param_grid=param_grid, 
                  scoring='neg_mean_squared_error', 
                  cv=5,
                  n_jobs=-1)

# %%
# Get parameter names
for k, v in gs.get_params().items():
    print(f"{k:35.35s}: {str(v)}")
# Out:
# cv                                 : 5
# error_score                        : nan
# estimator__C                       : 1.0
# estimator__cache_size              : 200
# estimator__coef0                   : 0.0
# estimator__degree                  : 3
# estimator__epsilon                 : 0.1
# estimator__gamma                   : scale
# estimator__kernel                  : rbf
# estimator__max_iter                : -1
# estimator__shrinking               : True
# estimator__tol                     : 0.001
# estimator__verbose                 : False
# estimator                          : SVR()
# n_jobs                             : -1
# param_grid                         : [{'C': [0.0001, 0.001, 0.01, 0.1, 1.0, 10.0, 100.0, 1000.0], 'kernel': ['linear']}, {'C': [0.0001, 0.001, 0.01, 0.1, 1.0, 10.0, 100.0, 1000.0], 'gamma': [0.0001, 0.001, 0.01, 0.1, 1.0, 10.0, 100.0, 1000.0], 'kernel': ['rbf']}]
# pre_dispatch                       : 2*n_jobs
# refit                              : True
# return_train_score                 : False
# scoring                            : neg_mean_squared_error
# verbose                            : 0

# %% [markdown]
# ### Training

# %%
gs.fit(X_train_std,y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVR(), n_jobs=-1,
#              param_grid=[{'C': [0.0001, 0.001, 0.01, 0.1, 1.0, 10.0, 100.0,
#                                 1000.0],
#                           'kernel': ['linear']},
#                          {'C': [0.0001, 0.001, 0.01, 0.1, 1.0, 10.0, 100.0,
#                                 1000.0],
#                           'gamma': [0.0001, 0.001, 0.01, 0.1, 1.0, 10.0, 100.0,
#                                     1000.0],
#                           'kernel': ['rbf']}],
#              scoring='neg_mean_squared_error')

# %%
df = pd.DataFrame(gs.cv_results_)
print(df.shape)
display(df.head())
# Out:
# (72, 16)
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0       0.004210      0.000290         0.001096    7.713961e-05  0.0001
# 1       0.004122      0.000425         0.001046    2.098083e-06   0.001
# 2       0.003778      0.000223         0.001042    2.153119e-05    0.01
# 3       0.003619      0.000503         0.000999    7.478899e-07     0.1
# 4       0.005109      0.000736         0.000704    4.009440e-04     1.0
#
#   param_kernel param_gamma                             params  \
# 0       linear         NaN  {'C': 0.0001, 'kernel': 'linear'}
# 1       linear         NaN   {'C': 0.001, 'kernel': 'linear'}
# 2       linear         NaN    {'C': 0.01, 'kernel': 'linear'}
# 3       linear         NaN     {'C': 0.1, 'kernel': 'linear'}
# 4       linear         NaN     {'C': 1.0, 'kernel': 'linear'}
#
#    split0_test_score  split1_test_score  split2_test_score  split3_test_score  \
# 0         -72.396781         -58.119588         -86.219069        -130.861376
# 1         -70.306888         -56.284045         -83.866296        -127.823041
# 2         -55.996471         -44.417588         -68.228734        -106.866318
# 3         -37.913040         -32.934327         -44.492693         -77.335299
# 4         -34.684879         -32.234355         -38.762849         -68.796371
#
#    split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0         -84.919782       -86.503319       24.392032               56
# 1         -82.414877       -84.139030       23.994033               47
# 2         -64.608844       -68.023591       21.082481               37
# 3         -39.907262       -46.516524       15.849739               28
# 4         -34.055135       -41.706718       13.711997               22

# %%
df = df.sort_values(by=['rank_test_score'])
display(df.head())
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 67       0.010915      0.000488         0.003592        0.001047  1000.0
# 53       0.006614      0.000663         0.003481        0.000448    10.0
# 52       0.011902      0.012559         0.003587        0.000356    10.0
# 60       0.014935      0.013839         0.004125        0.000919   100.0
# 61       0.011910      0.003766         0.006609        0.005833   100.0
#
#    param_kernel param_gamma                                        params  \
# 67          rbf         0.1  {'C': 1000.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 53          rbf        10.0   {'C': 10.0, 'gamma': 10.0, 'kernel': 'rbf'}
# 52          rbf         1.0    {'C': 10.0, 'gamma': 1.0, 'kernel': 'rbf'}
# 60          rbf         1.0   {'C': 100.0, 'gamma': 1.0, 'kernel': 'rbf'}
# 61          rbf        10.0  {'C': 100.0, 'gamma': 10.0, 'kernel': 'rbf'}
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 67         -24.955601         -22.565049         -25.035532
# 53         -24.694972         -21.360634         -26.851402
# 52         -26.048003         -22.190452         -24.707081
# 60         -25.613342         -22.102335         -29.149374
# 61         -24.740151         -22.495047         -28.276952
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 67         -50.304312         -21.284258       -28.828950       10.832755
# 53         -49.551585         -22.955535       -29.082826       10.395947
# 52         -51.087331         -22.382947       -29.283163       10.997710
# 60         -49.933217         -21.201774       -29.600008       10.547809
# 61         -50.295533         -24.060930       -29.973723       10.335734
#
#     rank_test_score
# 67                1
# 53                2
# 52                3
# 60                4
# 61                5

# %% [markdown]
# ### Refitting
# - Note that grid search already refit the entire training data with the best parameters. You can check this from this setting.

# %%
gs.refit
# Out:
# True

# %%
print(gs.best_score_)
print(gs.best_params_)
# Out:
# -28.828950253331676
# {'C': 1000.0, 'gamma': 0.1, 'kernel': 'rbf'}

# %%
y_pred = gs.predict(X_test_std)
print(mean_absolute_percentage_error(y_test, y_pred))
# Out:
# 0.1781562895108512
