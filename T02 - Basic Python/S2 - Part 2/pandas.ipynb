# %%
import pandas as pd

# %%
data = {
    'apples': [3, 2, 0, 1], 
    'oranges': [0, 3, 7, 2]
}

# %%
purchases = pd.DataFrame(data, index=['June', 'Robert', 'Lily', 'David'])

# %%
purchases
# Out:
#         apples  oranges
# June         3        0
# Robert       2        3
# Lily         0        7
# David        1        2

# %%
purchases.loc[["June","Robert","David"]]
# Out:
#         apples  oranges
# June         3        0
# Robert       2        3
# David        1        2

# %%
purchases[["oranges"]]
# Out:
#         oranges
# June          0
# Robert        3
# Lily          7
# David         2

# %%
purchases.loc[["Lily","Robert"], ["apples","oranges"]]
# Out:
#         apples  oranges
# Lily         0        7
# Robert       2        3

# %%
purchases.loc["Lily":"David", "apples":"oranges"]
# Out:
#        apples  oranges
# Lily        0        7
# David       1        2

# %%
purchases.to_csv("purchases.csv")

# %%
purchases.to_excel("purchases.xlsx")

# %%
purchases_import = pd.read_excel("purchases.xlsx", index_col=0)

# %%
purchases_import
# Out:
#         apples  oranges
# June         3        0
# Robert       2        3
# Lily         0        7
# David        1        2

# %%
movies_df = pd.read_csv("IMDB-Movie-Data.csv", index_col="Title")

# %%
movies_df.head(2)
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
#
#                              Director  \
# Title
# Guardians of the Galaxy    James Gunn
# Prometheus               Ridley Scott
#
#                                                                     Actors  \
# Title
# Guardians of the Galaxy  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Prometheus               Noomi Rapace, Logan Marshall-Green, Michael Fa...
#
#                          Year  Runtime (Minutes)  Rating   Votes  \
# Title
# Guardians of the Galaxy  2014                121     8.1  757074
# ...

# %%
movies_df.tail(2)
# Out:
#               Rank                  Genre  \
# Title
# Search Party   999       Adventure,Comedy
# Nine Lives    1000  Comedy,Family,Fantasy
#
#                                                     Description  \
# Title
# Search Party  A pair of friends embark on a mission to reuni...
# Nine Lives    A stuffy businessman finds himself trapped ins...
#
#                       Director  \
# Title
# Search Party    Scot Armstrong
# Nine Lives    Barry Sonnenfeld
#
#                                                          Actors  Year  \
# Title
# Search Party  Adam Pally, T.J. Miller, Thomas Middleditch,Sh...  2014
# Nine Lives    Kevin Spacey, Jennifer Garner, Robbie Amell,Ch...  2016
#
#               Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# Title
# Search Party                 93     5.6   4881                 NaN       22.0
# Nine Lives                   87     5.3  12435               19.64       11.0

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, Guardians of the Galaxy to Nine Lives
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Genre               1000 non-null   object
#  2   Description         1000 non-null   object
#  3   Director            1000 non-null   object
#  4   Actors              1000 non-null   object
#  5   Year                1000 non-null   int64
#  6   Runtime (Minutes)   1000 non-null   int64
#  7   Rating              1000 non-null   float64
#  8   Votes               1000 non-null   int64
#  9   Revenue (Millions)  872 non-null    float64
#  10  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 93.8+ KB

# %%
movies_df.rename(columns={
   'Runtime': 'Runtime (Minutes)', 
    'Revenue': 'Revenue_millions (Millions)'
}, inplace=True)

# %%
movies_df = movies_df.rename(columns={
   'Runtime (Minutes)': 'Runtime', 
    'Revenue (Millions)': 'Revenue_millions'
})

# %%
movies_df.head(2)
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
#
#                              Director  \
# Title
# Guardians of the Galaxy    James Gunn
# Prometheus               Ridley Scott
#
#                                                                     Actors  \
# Title
# Guardians of the Galaxy  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Prometheus               Noomi Rapace, Logan Marshall-Green, Michael Fa...
#
#                          Year  Runtime  Rating   Votes  Revenue_millions  \
# Title
# Guardians of the Galaxy  2014      121     8.1  757074            333.13
# ...

# %%
movies_df.columns = ['rank', 'genre', 'description', 'director', 'actors', 'year', 'runtime', 
                     'rating', 'votes', 'revenue_millions', 'metascore']

# %%
movies_df.head(2)
# Out:
#                          rank                     genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
#
#                                                                description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
#
#                              director  \
# Title
# Guardians of the Galaxy    James Gunn
# Prometheus               Ridley Scott
#
#                                                                     actors  \
# Title
# Guardians of the Galaxy  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Prometheus               Noomi Rapace, Logan Marshall-Green, Michael Fa...
#
#                          year  runtime  rating   votes  revenue_millions  \
# Title
# Guardians of the Galaxy  2014      121     8.1  757074            333.13
# ...

# %%
c = movies_df.columns
cnew = []
for name in c:
    cnew.append(name.upper())

movies_df.columns = cnew

movies_df.columns
# Out:
# Index(['RANK', 'GENRE', 'DESCRIPTION', 'DIRECTOR', 'ACTORS', 'YEAR', 'RUNTIME',
#        'RATING', 'VOTES', 'REVENUE_MILLIONS', 'METASCORE'],
#       dtype='object')

# %%
movies_df.head(2)
# Out:
#                          RANK                     GENRE  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
#
#                                                                DESCRIPTION  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
#
#                              DIRECTOR  \
# Title
# Guardians of the Galaxy    James Gunn
# Prometheus               Ridley Scott
#
#                                                                     ACTORS  \
# Title
# Guardians of the Galaxy  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Prometheus               Noomi Rapace, Logan Marshall-Green, Michael Fa...
#
#                          YEAR  RUNTIME  RATING   VOTES  REVENUE_MILLIONS  \
# Title
# Guardians of the Galaxy  2014      121     8.1  757074            333.13
# ...

# %%
# pd.read_excel('purchases.xlsx', sheet_name="Sheet2")

# %%
movies_df.columns = [col.lower() for col in movies_df]

movies_df.columns
# Out:
# Index(['rank', 'genre', 'description', 'director', 'actors', 'year', 'runtime',
#        'rating', 'votes', 'revenue_millions', 'metascore'],
#       dtype='object')

# %%
movies_df.head(2)
# Out:
#                          rank                     genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
#
#                                                                description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
#
#                              director  \
# Title
# Guardians of the Galaxy    James Gunn
# Prometheus               Ridley Scott
#
#                                                                     actors  \
# Title
# Guardians of the Galaxy  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Prometheus               Noomi Rapace, Logan Marshall-Green, Michael Fa...
#
#                          year  runtime  rating   votes  revenue_millions  \
# Title
# Guardians of the Galaxy  2014      121     8.1  757074            333.13
# ...

# %%
movies_df.describe()
# Out:
#               rank         year      runtime       rating         votes  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000   113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962    18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000    66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000   100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000   111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000   123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000   191.000000     9.000000  1.791916e+06
#
#        revenue_millions   metascore
# count        872.000000  936.000000
# mean          82.956376   58.985043
# std          103.253540   17.194757
# min            0.000000   11.000000
# 25%           13.270000   47.000000
# 50%           47.985000   59.500000
# 75%          113.715000   72.000000
# ...

# %%
movies_df.loc[:,["rank","actors", "runtime"]].describe()
# Out:
#               rank      runtime
# count  1000.000000  1000.000000
# mean    500.500000   113.172000
# std     288.819436    18.810908
# min       1.000000    66.000000
# 25%     250.750000   100.000000
# 50%     500.500000   111.000000
# 75%     750.250000   123.000000
# max    1000.000000   191.000000

# %%
movies_df.loc[:, ["genre"]].value_counts().head(20)
# Out:
# genre
# Action,Adventure,Sci-Fi       50
# Drama                         48
# Comedy,Drama,Romance          35
# Comedy                        32
# Drama,Romance                 31
# Action,Adventure,Fantasy      27
# Comedy,Drama                  27
# Animation,Adventure,Comedy    27
# Comedy,Romance                26
# Crime,Drama,Thriller          24
# Crime,Drama,Mystery           23
# Action,Adventure,Drama        18
# Action,Crime,Drama            17
# Horror,Thriller               16
# Drama,Thriller                15
# Biography,Drama               14
# Action,Adventure,Comedy       14
# Adventure,Family,Fantasy      14
# Biography,Drama,History       14
# Action,Comedy,Crime           12
# Name: count, dtype: int64

# %%
# movies_df.loc[:,:]
# movies_df.loc[["Guardians of the Galaxy", "Prometheus", "Split"],:]
# movies_df.loc[["Guardians of the Galaxy", "Prometheus", "Split"]]
movies_df.loc["Guardians of the Galaxy":"Split"]
# Out:
#                          rank                     genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
#
#                                                                description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
#
#                                    director  \
# Title
# Guardians of the Galaxy          James Gunn
# Prometheus                     Ridley Scott
# Split                    M. Night Shyamalan
#
#                                                                     actors  \
# Title
# Guardians of the Galaxy  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# ...

# %%
# movies_df.loc[:,["rank","genre","description"]]
movies_df[["rank","genre","description"]]
# Out:
#                          rank                     genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                description
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
movies_df.iloc[0:10,0:3]
# Out:
#                          rank                       genre  \
# Title
# Guardians of the Galaxy     1     Action,Adventure,Sci-Fi
# Prometheus                  2    Adventure,Mystery,Sci-Fi
# Split                       3             Horror,Thriller
# Sing                        4     Animation,Comedy,Family
# Suicide Squad               5    Action,Adventure,Fantasy
# The Great Wall              6    Action,Adventure,Fantasy
# La La Land                  7          Comedy,Drama,Music
# Mindhorn                    8                      Comedy
# The Lost City of Z          9  Action,Adventure,Biography
# Passengers                 10     Adventure,Drama,Romance
#
#                                                                description
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# ...

# %%
# movies_df.loc[:,["director"]]
movies_df[["director"]] == "Ridley Scott"
# Out:
#                          director
# Title
# Guardians of the Galaxy     False
# Prometheus                   True
# Split                       False
# Sing                        False
# Suicide Squad               False
# ...                           ...
# Secret in Their Eyes        False
# Hostel: Part II             False
# Step Up 2: The Streets      False
# Search Party                False
# Nine Lives                  False
#
# [1000 rows x 1 columns]

# %%
a = movies_df[["director"]]
b = movies_df["director"]

# %%
movies_df["director"] == "Ridley Scott"
# Out:
# Title
# Guardians of the Galaxy    False
# Prometheus                  True
# Split                      False
# Sing                       False
# Suicide Squad              False
#                            ...
# Secret in Their Eyes       False
# Hostel: Part II            False
# Step Up 2: The Streets     False
# Search Party               False
# Nine Lives                 False
# Name: director, Length: 1000, dtype: bool

# %%
# filt = movies_df["director"] == "Ridley Scott"
# filt = movies_df["director"] == "Christopher Nolan"
# filt = movies_df["rating"] > 8
filt_director = (movies_df["director"] == "Ridley Scott") | (movies_df["director"] == "Christopher Nolan") 
filt_rating = movies_df["rating"] > 8
movies_df[filt_director & filt_rating].sort_values(by="rating", ascending=False)
# Out:
#                        rank                    genre  \
# Title
# The Dark Knight          55       Action,Crime,Drama
# Inception                81  Action,Adventure,Sci-Fi
# Interstellar             37   Adventure,Drama,Sci-Fi
# The Prestige             65     Drama,Mystery,Sci-Fi
# The Dark Knight Rises   125          Action,Thriller
#
#                                                              description  \
# Title
# The Dark Knight        When the menace known as the Joker wreaks havo...
# Inception              A thief, who steals corporate secrets through ...
# Interstellar           A team of explorers travel through a wormhole ...
# The Prestige           Two stage magicians engage in competitive one-...
# The Dark Knight Rises  Eight years after the Joker's reign of anarchy...
#
#                                 director  \
# Title
# The Dark Knight        Christopher Nolan
# Inception              Christopher Nolan
# Interstellar           Christopher Nolan
# ...

# %%
movies_df["rating_category"] = 100

# %%
movies_df.to_excel("test.xlsx")

# %%
def rating_function(entry):
    if entry > 8:
        return "Good"
    else:
        return "Bad"

movies_df["rating_category"] = movies_df["rating"].apply(rating_function)

# %%
movies_df
# Out:
#                          rank                     genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...
